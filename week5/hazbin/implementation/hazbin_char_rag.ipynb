# %% [markdown]
# #Hazbin Hotel Character RAG System

# %%
import os
import json
import gradio as gr
from pathlib import Path
from langchain_core.documents import Document
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_chroma import Chroma
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_core.messages import SystemMessage, HumanMessage, convert_to_messages
from dotenv import load_dotenv

# %%
DB_NAME = "hazbin_character.db"

MODEL = "gpt-4.1-nano"
RETRIEVAL_K = 3
load_dotenv(override=True)

embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

# %%
def fetch_hazbin_data():
    # __file__ is not defined in notebooks; instead, resolve relative to notebook location or use cwd
    # We'll assume the notebook is run from within the "implementation" folder, or adjust as needed
    hazbin_base = Path.cwd().parent / "knowledge-base"
    ljson_path = hazbin_base / "hazbin_character_profiles.ljson"
    documents = []
    if ljson_path.exists():
        with open(ljson_path, "r", encoding="utf-8") as f:
            # Each line is a JSON object
            for line in f:
                line = line.strip()
                if not line:
                    continue
                data = json.loads(line)
                content = data.get("description") or data.get("bio") or json.dumps(data)
                metadata = {k: v for k, v in data.items() if k != "description" and k != "bio"}
                documents.append(Document(page_content=content, metadata=metadata))
    return documents

# %%
# Display documents as a test
documents = fetch_hazbin_data()
for i, doc in enumerate(documents[:5]):
    print(f"Document {i+1}:")
    print("Content:", doc.page_content)
    print("Metadata:", doc.metadata)
    print("-" * 40)
# Out:
# Document 1:
# Content: Charlotte "Charlie" Morningstar is the protagonist and princess of Hell who founds the Hazbin Hotel to rehabilitate sinners and reduce Hell's overpopulation.
# Metadata: {'name': 'Charlie Morningstar', 'appearance': 'Tall humanoid demoness with pale skin, long pink hair with orange tips, a red dress with star motifs and a crown-like hair accessory; generally bright, theatrical design.', 'personality': 'Optimistic, compassionate, idealistic, earnest and determined; deeply empathetic and often naively hopeful about redemption.', 'backstory': "Daughter of Lucifer Morningstar and Lilith, Charlie grew up in Hell and became determined to find a nonviolent solution to Hell's problems. She opens the Hazbin Hotel to rehabilitate sinners and seeks a path to Heaven for redeemed souls."}
# ----------------------------------------
# Document 2:
# Content: Vaggie (often spelled Vaggi) is Charlie's girlfriend and the manager/defender of the Hazbin Hotel; a fallen angel and former Exorcist.
# Metadata: {'name': 'Vaggie', 'appearance': 'Humanoid with grayish-lavender skin, short white hair with a dark streak, an eyepatch over her right eye (lost in past conflict), and practical dark clothing; moth-themed visual elements.', 'personality': 'Protective, pragmatic, fierce and no-nonsense; deeply loyal to Charlie and quick to anger when the hotel or people she cares for are threatened.', 'backstory': "Once an Exorcist/angel who fought in Extermination raids, Vaggie was left behind during an operation, survived, and later met Charlie. She became her partner in running the Hazbin Hotel and left the Exorcists, dedicating herself to Charlie's cause."}
# ----------------------------------------
# Document 3:
# Content: Angel Dust is a flamboyant, fast-talking sinner and former human adult film actor who becomes one of the hotel's first residents attempting redemption.
# Metadata: {'name': 'Angel Dust', 'appearance': 'Tall, spider-like demon with white-pink fur, multiple markings, a white suit with pinstripes, pink hair and heavy makeup; visually reminiscent of an old-school showbiz look.', 'personality': 'Charismatic, sarcastic, self-destructive, streetwise and humorous; hides vulnerabilities beneath bravado but has moments of genuine warmth.', 'backstory': 'Born human and dragged into vice during life, Angel Dust arrived in Hell and ended up under the sway of the Vees (notably Valentino). He checks into the Hazbin Hotel amid conflicting motives, oscillating between self-interest and potential change.'}
# ----------------------------------------
# Document 4:
# Content: Alastor, known as the Radio Demon, is an ancient and powerful overlord of Hell who offers to help Charlie run the hotel — though his motives and appetite for chaos are ambiguous.
# Metadata: {'name': 'Alastor (Radio Demon)', 'appearance': 'Tall, gaunt humanoid with red-and-black themed attire, pinstriped suit, deer-like antlers, a permanent grin, and stylized 1930s radio-era visual motifs; often accompanied by static and radio effects.', 'personality': 'Polite, theatrical, sadistic, manipulative and enigmatic; enjoys theatrics and reworking reality to suit his whims while masking true intent in old-timey radio charm.', 'backstory': 'A legendary figure in Hell with immense powers and a history of deals and entertainment-themed atrocities. He rose to prominence long before the present timeline; he agreed to assist Charlie but always with strings attached and an appetite for influence.'}
# ----------------------------------------
# Document 5:
# Content: Husk is the grumpy bartender at the Hazbin Hotel who serves drinks and acts as part of the hotel's staff and reluctant caretaker.
# Metadata: {'name': 'Husk', 'appearance': 'Anthropomorphic cat-like demon with scruffy fur, drooping eyes, a cigarette, and a vest; often seen with a drink in hand and a perpetually tired posture.', 'personality': 'World-weary, sarcastic, cynical and occasionally irritable, but dependable and quietly caring beneath his gruff exterior.', 'backstory': "A long-time denizen of Hell with a gambling and drinking past, Husk took a job at the Hazbin Hotel as bartender. He has a rough history that fuels his cynical outlook but he remains part of Charlie's experiment in redemption."}
# ----------------------------------------

# %%
def create_chunks(documents):
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=200, chunk_overlap=50)
    chunks = text_splitter.split_documents(documents)
    return chunks

# %%
chunks = create_chunks(documents)

chunks
# Out:
# [Document(metadata={'name': 'Charlie Morningstar', 'appearance': 'Tall humanoid demoness with pale skin, long pink hair with orange tips, a red dress with star motifs and a crown-like hair accessory; generally bright, theatrical design.', 'personality': 'Optimistic, compassionate, idealistic, earnest and determined; deeply empathetic and often naively hopeful about redemption.', 'backstory': "Daughter of Lucifer Morningstar and Lilith, Charlie grew up in Hell and became determined to find a nonviolent solution to Hell's problems. She opens the Hazbin Hotel to rehabilitate sinners and seeks a path to Heaven for redeemed souls."}, page_content='Charlotte "Charlie" Morningstar is the protagonist and princess of Hell who founds the Hazbin Hotel to rehabilitate sinners and reduce Hell\'s overpopulation.'),
#  Document(metadata={'name': 'Vaggie', 'appearance': 'Humanoid with grayish-lavender skin, short white hair with a dark streak, an eyepatch over her right eye (lost in past conflict), and practical dark clothing; moth-themed visual elements.', 'personality': 'Protective, pragmatic, fierce and no-nonsense; deeply loyal to Charlie and quick to anger when the hotel or people she cares for are threatened.', 'backstory': "Once an Exorcist/angel who fought in Extermination raids, Vaggie was left behind during an operation, survived, and later met Charlie. She became her partner in running the Hazbin Hotel and left the Exorcists, dedicating herself to Charlie's cause."}, page_content="Vaggie (often spelled Vaggi) is Charlie's girlfriend and the manager/defender of the Hazbin Hotel; a fallen angel and former Exorcist."),
#  Document(metadata={'name': 'Angel Dust', 'appearance': 'Tall, spider-like demon with white-pink fur, multiple markings, a white suit with pinstripes, pink hair and heavy makeup; visually reminiscent of an old-school showbiz look.', 'personality': 'Charismatic, sarcastic, self-destructive, streetwise and humorous; hides vulnerabilities beneath bravado but has moments of genuine warmth.', 'backstory': 'Born human and dragged into vice during life, Angel Dust arrived in Hell and ended up under the sway of the Vees (notably Valentino). He checks into the Hazbin Hotel amid conflicting motives, oscillating between self-interest and potential change.'}, page_content="Angel Dust is a flamboyant, fast-talking sinner and former human adult film actor who becomes one of the hotel's first residents attempting redemption."),
#  Document(metadata={'name': 'Alastor (Radio Demon)', 'appearance': 'Tall, gaunt humanoid with red-and-black themed attire, pinstriped suit, deer-like antlers, a permanent grin, and stylized 1930s radio-era visual motifs; often accompanied by static and radio effects.', 'personality': 'Polite, theatrical, sadistic, manipulative and enigmatic; enjoys theatrics and reworking reality to suit his whims while masking true intent in old-timey radio charm.', 'backstory': 'A legendary figure in Hell with immense powers and a history of deals and entertainment-themed atrocities. He rose to prominence long before the present timeline; he agreed to assist Charlie but always with strings attached and an appetite for influence.'}, page_content='Alastor, known as the Radio Demon, is an ancient and powerful overlord of Hell who offers to help Charlie run the hotel — though his motives and appetite for chaos are ambiguous.'),
#  Document(metadata={'name': 'Husk', 'appearance': 'Anthropomorphic cat-like demon with scruffy fur, drooping eyes, a cigarette, and a vest; often seen with a drink in hand and a perpetually tired posture.', 'personality': 'World-weary, sarcastic, cynical and occasionally irritable, but dependable and quietly caring beneath his gruff exterior.', 'backstory': "A long-time denizen of Hell with a gambling and drinking past, Husk took a job at the Hazbin Hotel as bartender. He has a rough history that fuels his cynical outlook but he remains part of Charlie's experiment in redemption."}, page_content="Husk is the grumpy bartender at the Hazbin Hotel who serves drinks and acts as part of the hotel's staff and reluctant caretaker."),
#  Document(metadata={'name': 'Niffty', 'appearance': 'Small, retro-styled female demon with large expressive eyes, short hair, a frilly maid outfit, and vintage 1950s housemaid aesthetics.', 'personality': 'Bubbly, enthusiastic, excitable, obsessive about cleanliness and domestic order; shows childlike curiosity and loyalty.', 'backstory': 'A resident of Hell who gravitated toward service and domestic work; Niffty joined the Hazbin Hotel staff, thriving on being useful and on the social aspects of helping others rehabilitate.'}, page_content="Niffty is the energetic, hyperactive maid and housekeeper for the Hazbin Hotel who cleans, decorates and helps maintain the hotel's day-to-day operations."),
#  Document(metadata={'name': 'Sir Pentious', 'appearance': 'Snake-themed Victorian/steampunk-styled demon with goggles, a long cape, mechanical apparatuses, and serpentine motifs; often accompanied by contraptions and schemes.', 'personality': 'Grandiose, theatrical, petty, vengeful and melodramatic; obsessed with inventions and getting recognition as a true villain.', 'backstory': "A once-human or early-sinner figure who adopted a villain persona in Hell, Sir Pentious builds devices and stages plots. He clashed with Charlie and the hotel's residents and later becomes entangled in larger conflicts in Hell."}, page_content='Sir Pentious is a recurring antagonist: a self-styled villainous inventor with an over-the-top personality and vendetta against established powers.'),
#  Document(metadata={'name': 'Cherri Bomb', 'appearance': 'Punk rock aesthetic with bright hair, goggles or eye markings, combat-style clothing, and explosive-themed accessories; dynamic and edgy design.', 'personality': 'Fiery, impulsive, bold and volatile but protective of friends; enjoys chaos but can show loyalty.', 'backstory': "A sinner with a violent, tumultuous past who operates on the fringes of Hell's underworld. She has crossed paths with the Hazbin Hotel residents and participates in the conflicts and defense of the hotel at times."}, page_content="Cherri Bomb is an explosive-minded, punk-styled sinner and frequent ally/enforcer figure who appears as part of the hotel's extended cast of residents and Hell's rougher element."),
#  Document(metadata={'name': 'Razzle', 'appearance': 'Small red-furred demon with long horns, yellow eyes, and matching attire to his brother/partner Dazzle; cute but sinister design.', 'personality': 'Loyal, dutiful and protective, acting as a bodyguard and attendant to Charlie and the royal household.', 'backstory': 'One of two members (Razzle and Dazzle) who historically served the Morningstar family. The pair appear as childhood-era attendants; Dazzle was killed during early conflicts, leaving Razzle as survivor and symbol of that loss.'}, page_content="Razzle is one half of a small pair of red-furred attendants/bodyguards who have ties to Charlie's royal household in Hell."),
#  Document(metadata={'name': 'Dazzle', 'appearance': 'Small red-furred demon like Razzle with horns and matching clothing; visually paired with Razzle.', 'personality': "Devoted and dutiful as a royal attendant; mirrors Razzle's loyalty.", 'backstory': "Served alongside Razzle in the Morningstar retinue; Dazzle is killed during an early Exorcist attack, an event with consequences for characters tied to Charlie's history."}, page_content="Dazzle is Razzle's counterpart — a small attendant who appears in the series' early sequences and whose fate impacts other characters."),
#  Document(metadata={'name': 'KeeKee (Keekee)', 'appearance': 'Cat-like demonic creature with a single large eye (red iris), extra eyes/mouths hidden in its tail at times, and small compact form; appears both as a pet and symbolic key.', 'personality': 'Playful, enigmatic, and occasionally mischievous; nonverbal but affectionate toward Charlie and the hotel.', 'backstory': "KeeKee first appears as Charlie's pet and is tied to the hotel's nature — often treated as the literal key to the hotel and a living manifestation of the establishment's essence."}, page_content="KeeKee (often stylized KeeKee) is a mysterious small creature who serves as Charlie's pet and the living key/embodiment of the Hazbin Hotel."),
#  Document(metadata={'name': 'Rosie', 'appearance': 'Tall, thin demoness with pale skin, wide mouth full of sharp teeth, black eyes without irises, dusty-pink cheeks and elegant but eerie attire; theatrical and commanding presence.', 'personality': 'Manipulative, charismatic, theatrical, calculating and confident; can be friendly publicly but is ruthless in protecting her domain and influence.', 'backstory': "A long-established Overlord who controls Cannibal Town and owns Rosie's Emporium. She becomes involved in wider politics of Hell, Alastor's network and the rivalries between Overlords and the Vees."}, page_content="Rosie is a powerful Overlord in Hell and the proprietor of Rosie's Emporium and ruler of Cannibal Town; a significant supporting figure in Hell's power structure."),
#  Document(metadata={'name': 'Baxter', 'appearance': 'Shorter blue-toned demon with aquatic/anglerfish motifs, goggles, rounded head, and lab-inventor aesthetic; insectile/angryfish features.', 'personality': 'Awkward, curious, socially anxious, obsessive about experiments and scientific curiosity; earnest and somewhat twitchy.', 'backstory': "A former collaborator with Sir Pentious who later worked at VoxTek. Baxter dies in history prior to some events but is depicted/introduced in Season 2 as a figure who came to the hotel to test or witness Charlie's experiment in redemption."}, page_content='Baxter is a nervous, anglerfish-inspired mad scientist and former employee of VoxTek who appears as a hotel resident and supporting character.'),
#  Document(metadata={'name': 'Abel', 'appearance': 'Young, golden/white-clad angel with classical angelic design cues; often shown with a noble, radiant aesthetic befitting a Heaven-aligned character.', 'personality': 'Earnest, dutiful, principled and driven by a sense of duty; can be proud and zealous as an Exorcist commander figure.', 'backstory': "Introduced as the son of Adam and a rising angelic figure among the Exorcists; Abel assumes command roles and becomes central in Heaven's conflicts with Hell following Season 1 events."}, page_content='Abel is an angelic figure introduced in later episodes — a young angel and son of Adam — who becomes a major supporting character in Season 2.'),
#  Document(metadata={'name': 'Adam', 'appearance': 'Tall, imposing angelic figure with golden-white armor and classical heroic design; regal, martial presence.', 'personality': "Arrogant, zealous, militant and uncompromising; views extermination of sinners as duty and upholds Heaven's harsh policies.", 'backstory': "Based on the biblical first man, Adam became the commander of the Exorcists after death and led Heaven's annual exterminations of Hell. He served as a major antagonist in the show's initial conflict and met a violent fate during events surrounding the Hazbin Hotel."}, page_content="Adam is the First Man turned powerful angel who served as the commander of Heaven's Exorcist army and a principal antagonist in Season 1."),
#  Document(metadata={'name': 'Lute', 'appearance': "Angel/Exorcist with warlike armor, scars and a grim demeanor; looks like a hardened warrior aligned with Heaven's military aesthetic.", 'personality': "Ruthless, vengeful, hot-tempered and single-minded when pursuing anti-demon objectives; embodies the Exorcists' brutality.", 'backstory': "An Exorcist officer who participated in extermination raids and became central in the aftermath of Adam's death, asserting authority and continuing the campaign against Hell and Charlie's hotel."}, page_content='Lute is a lieutenant among the Exorcists who serves under Adam and later claims leadership; portrayed as violent and vengeful.'),
#  Document(metadata={'name': 'Vox', 'appearance': 'Tall, blocky, television-bodied overlord with retro-TV and neon motifs, screens for a face, and a slick, corporate aesthetic.', 'personality': 'Calculating, cold, media-savvy, manipulative and cruel; treats people as products and pursues profit and influence ruthlessly.', 'backstory': 'A powerful overlord who runs VoxTek and the Vees — a triumvirate of Overlords (Vox, Valentino, Velvette). Vox leverages media and technology to expand his power and to exploit instability between Hell and Heaven.'}, page_content="Vox is one of Hell's major Overlords — a media mogul and one-third of the Overlord trio known as the Vees; he exerts influence through electronics and media."),
#  Document(metadata={'name': 'Valentino', 'appearance': 'Tall, gaudy, slickly dressed demon with masculine porn-studio boss aesthetics, tattoo motifs, slick hair and predatory features; luxurious and sleazy attire.', 'personality': 'Predatory, controlling, lecherous, violent and self-indulgent; prioritizes profit, control and personal gratification.', 'backstory': 'A powerful overlord who runs porn and vice enterprises in Hell (V-Tower). He kept Angel Dust under his control and is a central antagonist as the hotel disrupts his business and challenges his authority.'}, page_content="Valentino is an Overlord and crime boss who controls a corner of Hell's vice industries and is notably Angel Dust's exploiter/manager; one of the Vees and a major villain."),
#  Document(metadata={'name': 'Velvette', 'appearance': 'Stylish demon with fashion-designer aesthetic, chic clothing, refined silhouette and palette emphasizing elegance and couture motifs.', 'personality': 'Image-conscious, authoritative, vain, sharp and controlling in social domains; less overtly violent than her Vee counterparts but cold and ambitious.', 'backstory': "Became the youngest Overlord and joined Vox and Valentino to form the Vees. She oversees branding, fashion and social influence in Hell and participates in the Overlords' attempts to manipulate Hell's politics."}, page_content='Velvette (sometimes Velvette/Velvet) is the fashion- and influence-focused member of the Vees, an Overlord who handles social media, branding and public image for the trio.'),
#  Document(metadata={'name': 'Lucifer Morningstar', 'appearance': 'Regal, imposing fallen angel with classic Morningstar motifs, tailored clothing and a commanding presence reflective of an infernal monarch.', 'personality': "Authoritative, charismatic, proud and complex; appears as a powerful patriarch balancing familial ties and Hell's politics.", 'backstory': "Long-established ruler and powerful figure in Hell, Lucifer fathered Charlie and has a fraught relationship with Lilith and his daughter. He appears at key moments during the series' political and personal conflicts."}, page_content="Lucifer Morningstar is Charlie's father, a major fallen-angel figure in Hell and an ancient, politically important character."),
#  Document(metadata={'name': 'Lilith', 'appearance': 'Elegant fallen angel/demonic queen with regal attire, pale skin and ornate design reflective of a maternal royal archetype.', 'personality': 'Reserved, dignified, stern and complex; carries the weight of past decisions and family history.', 'backstory': "Estranged wife of Lucifer and mother to Charlie. Lilith's history and the Morningstar family's past are central to the political and personal backdrops affecting Charlie and Hell's balance of power."}, page_content="Lilith is Charlie's mother and formerly queen figure; a significant figure tied to royal Morningstar family dynamics."),
#  Document(metadata={'name': 'Sera', 'appearance': "Angelic in white/gold tones with classical celestial motifs; formal armor or robes common to Heaven's forces.", 'personality': "Duty-driven, serious and mission-focused; represents Heaven's structured order in its conflict with Hell.", 'backstory': "A seraphic figure operating within Heaven's military/political framework. Sera appears in Season 2 sequences tied to the ongoing Heaven-Hell tensions and interactions with Charlie and the Hazbin Hotel."}, page_content="Sera is one of the angelic figures introduced in Season 2 material; a member of the heavenly order involved in the Exorcists/Heaven's affairs."),
#  Document(metadata={'name': 'Emily', 'appearance': "Young angelic figure in white/gold, with delicate features and attire consistent with Heaven's aesthetic.", 'personality': "Disciplined, earnest and aligned with the Exorcists' cause; sometimes presented as an exemplar of Heaven's values.", 'backstory': "A member of Heaven's ranks who participates in the larger conflict with Hell. Emily appears alongside other angelic characters in Season 2 scenes and promotional material."}, page_content="Emily is another angelic supporting character associated with Heaven's forces and the Exorcists; appears in promotional and Season 2 material."),
#  Document(metadata={'name': 'St. Peter', 'appearance': 'Traditional saintly/angelic visage with clerical and celestial iconography appropriate to a figure associated with divine gates and records.', 'personality': "Authoritative, solemn and bureaucratic; embodies Heaven's administrative structure and gatekeeping role.", 'backstory': "An angelic figure tied to Heaven's operations and mythos in the series, referenced in connection to redemption, gates of Heaven and the overarching spiritual bureaucracy that influences the show's stakes."}, page_content="St. Peter appears as a canonical angelic/religious figure referenced or depicted in the Hellaverse with duties tied to Heaven's bureaucracy and enforcement."),
#  Document(metadata={'name': 'Speaker of God', 'appearance': "Usually depicted symbolically or as a majestic, luminous presence rather than a traditional humanoid; used to represent God's proclamation and authority.", 'personality': 'Omniscient, absolute and inscrutable; projects incomprehensible authority and theocratic power.', 'backstory': "Serves as the ultimate divine or heavenly authority whose decrees and theocratic policies shape Heaven's approach to Hell and the Exorcists' annual exterminations; appears indirectly through angels and official pronouncements."}, page_content="The Speaker of God is a manifested heavenly voice/authority figure representing divine will and decrees within the Hellaverse's depiction of Heaven."),
#  Document(metadata={'name': 'Exorcists', 'appearance': 'Armored angelic soldiers with military/ceremonial armor, wings and weaponry; a unified martial visual design.', 'personality': 'Disciplined, zealous, militant and relentless as an organization; individual members vary from compassionate to ruthless.', 'backstory': 'Institutionalized heavenly military that carries out extermintation campaigns against Hell. Led at times by Adam and later other commanders (e.g., Lute, Abel), the Exorcists drive much of the conflict between Heaven and Hell.'}, page_content="The Exorcists are Heaven's military force — angels tasked with annual exterminations of sinners and raids into Hell to control the population and eliminate threats."),
#  Document(metadata={'name': 'Egg Boiz', 'appearance': 'Small, egg-shaped demonic creatures with simple features; cartoonish and stylized as background fauna of Hell.', 'personality': "Mostly mute, slapstick and comic-relief in nature; function as background extras adding tone and texture to Hell's populace.", 'backstory': 'Serve as background elements populating Hell; their appearances provide comedic and atmospheric color in crowd sequences and local scenes.'}, page_content="Egg Boiz are small background characters — a group of minor, comedic henchmen/background demons appearing in the series' crowd scenes and extras."),
#  Document(metadata={'name': 'Fat Nuggets', 'appearance': 'Small rotund creatures or motifs that visually resemble snack-like, pudgy beings used for comedic effect.', 'personality': 'Background comedic devices rather than individual characters; playful and silly in on-screen presentation.', 'backstory': "Primarily background/visual gags used by the series to populate Hell's ecosystem; they provide atmosphere and occasional comedic beats."}, page_content='Fat Nuggets are recurring gag/background creatures or food-themed denizens that appear throughout the Hellaverse as minor supporting/background visual elements.'),
#  Document(metadata={'name': 'Franklin', 'appearance': "Depictions are minimal in the show; often referenced in relation to Rosie's establishment and backstory.", 'personality': 'His presence is mainly historical/contextual rather than developed as an on-screen personality.', 'backstory': "Named as a deceased associate/co-owner tied to Rosie's Emporium, Franklin's fate contributes to Rosie's status and the political dynamics of Cannibal Town and Rosie's holdings."}, page_content="Franklin is a background/supporting figure referenced as a former co-owner or associate tied to Rosie's Emporium; his death is part of Rosie's backstory."),
#  Document(metadata={'name': "Sir Pentious's Creations (NPCs)", 'appearance': 'Diverse mechanical serpentine constructs, steam-powered devices and villainous contraptions in steampunk/serpentine styles.', 'personality': 'Non-sentient or semi-sentient threats used for conflict; behave according to creator directives.', 'backstory': "Built by Sir Pentious and other inventor-characters to pursue schemes, vendettas or to provide spectacle; they populate the rogues' gallery of Hell's lower-level criminal activity."}, page_content='Various mechanical and monstrous creations built by Sir Pentious and similar inventors serve as background antagonists or set-pieces in episodes.'),
#  Document(metadata={'name': 'Cannibal Town Locals (background)', 'appearance': "Diverse demonic designs emphasizing gaunt, macabre or culinary motifs; often presented as a stylized community under Rosie's rule.", 'personality': "Varied: gruff, hungry, theatrical or servile depending on role; mainly function to illustrate Hell's social strata.", 'backstory': "Populace that lives under Rosie’s influence in Cannibal Town and interacts with major players like Rosie, the Overlords and visiting protagonists; they provide social texture to Hell's world."}, page_content="Residents of Cannibal Town are supporting/background characters tied to Rosie's domain and are part of Hell's varied society in the series."),
#  Document(metadata={'name': 'Overlords (collective)', 'appearance': 'Each Overlord has a distinct, exaggerated design reflecting their domain (media, vice, fashion, cannibalism, radio lore), but as a class they are lavishly adorned and imposing.', 'personality': 'Arrogant, influential, predatory and politically driven; they compete for power, wealth and status across Hell.', 'backstory': "Ancient and established denizens of Hell who built empires, industries and territories over centuries; they shape Hell's political landscape and are major antagonists or power-brokers in the Hazbin Hotel story."}, page_content='Overlords are the powerful high-tier demons who rule territories, industries and institutions in Hell (e.g., Vox, Valentino, Velvette, Rosie, Alastor among the ranks).'),
#  Document(metadata={'name': "Alastor's Associates (background)", 'appearance': "Stylized henchmen/associates reflecting Alastor's radio/vaudeville motif, often with period clothing or thematic accessories.", 'personality': "Loyal to Alastor, theatrically inclined and occasionally sinister; perform errands and serve Alastor's schemes.", 'backstory': 'Individuals and minor powers who have aligned with or been employed by Alastor over the centuries; they operate within his sphere of influence during his interactions with the Hazbin Hotel.'}, page_content='Various aides, allies and minor characters orbit Alastor’s network, appearing as supporting figures in episodes involving Alastor or his interests.')]

# %%
def create_embeddings(chunks):
    if os.path.exists(DB_NAME):
        Chroma(persist_directory=DB_NAME, embedding_function=embeddings).delete_collection()

    vectorstore = Chroma.from_documents(
        documents=chunks, embedding=embeddings, persist_directory=DB_NAME
    )

    collection = vectorstore._collection
    count = collection.count()

    sample_embedding = collection.get(limit=1, include=["embeddings"])["embeddings"][0]
    dimensions = len(sample_embedding)
    print(f"There are {count:,} vectors with {dimensions:,} dimensions in the vector store")
    return vectorstore

# %%
documents = fetch_hazbin_data()
chunks = create_chunks(documents)
vectorstore = create_embeddings(chunks)
print("Ingestion complete")
# Out:
# There are 33 vectors with 1,536 dimensions in the vector store
# Ingestion complete

# %%
SYSTEM_PROMPT = """
You are a knowledgeable, friendly assistant who helps fans of Hazbin Hotel.
You are chatting with a user about Hazbin Hotel Characters.
If relevant, use the given context to answer any question.
If you don't know the answer, say so.
Context:
{context}
"""
retriever = vectorstore.as_retriever()
llm = ChatOpenAI(temperature=0, model_name=MODEL)

# %%
def fetch_context(question: str) -> list[Document]:
    """
    Retrieve relevant context documents for a question.
    """
    return retriever.invoke(question, k=RETRIEVAL_K)

# %%
def combined_question(question: str, history: list[dict] = []) -> str:
    """
    Combine all the user's messages into a single string.
    """
    prior = "\n".join(m["content"] for m in history if m["role"] == "user")
    return prior + "\n" + question

# %%
def answer_question(question: str, history: list[dict] = []) -> tuple[str, list[Document]]:
    """
    Answer the given question with RAG; return the answer and the context documents.
    """
    combined = combined_question(question, history)
    docs = fetch_context(combined)
    context = "\n\n".join(doc.page_content for doc in docs)
    system_prompt = SYSTEM_PROMPT.format(context=context)
    messages = [SystemMessage(content=system_prompt)]
    messages.extend(convert_to_messages(history))
    messages.append(HumanMessage(content=question))
    response = llm.invoke(messages)
    return response.content, docs

# %%
def format_context(context):
    result = "<h2 style='color: #ff7800;'>Relevant Context</h2>\n\n"
    for doc in context:
        result += f"<span style='color: #ff7800;'>Name: {doc.metadata['name']}</span>\n\n"
        result += doc.page_content + "\n\n"
    return result


def chat(history):
    last_message = history[-1]["content"]
    prior = history[:-1]
    answer, context = answer_question(last_message, prior)
    history.append({"role": "assistant", "content": answer})
    return history, format_context(context)


def main():
    def put_message_in_chatbot(message, history):
        return "", history + [{"role": "user", "content": message}]

    theme = gr.themes.Soft(font=["Inter", "system-ui", "sans-serif"])

    with gr.Blocks(title="Insurellm Expert Assistant", theme=theme) as ui:
        gr.Markdown("# 🏢 Insurellm Expert Assistant\nAsk me anything about Hazbin Hotel Characters!")

        with gr.Row():
            with gr.Column(scale=1):
                chatbot = gr.Chatbot(
                    label="💬 Conversation", height=600, type="messages", show_copy_button=True
                )
                message = gr.Textbox(
                    label="Your Question",
                    placeholder="Ask anything about Hazbin Hotel Characters...",
                    show_label=False,
                )

            with gr.Column(scale=1):
                context_markdown = gr.Markdown(
                    label="📚 Retrieved Context",
                    value="*Retrieved context will appear here*",
                    container=True,
                    height=600,
                )

        message.submit(
            put_message_in_chatbot, inputs=[message, chatbot], outputs=[message, chatbot]
        ).then(chat, inputs=chatbot, outputs=[chatbot, context_markdown])

    ui.launch(inbrowser=True)

# %%
main()
# Out:
# * Running on local URL:  http://127.0.0.1:7862
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
